# %%
from utils.statannotation_utils import *
from utils.utils import *

# %%
df = load_and_clean()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     200 non-null    object
#  1   diet                   200 non-null    object
#  2   rep                    200 non-null    int64
#  3   stage                  200 non-null    object
#  4   channel0_arr_vals_raw  200 non-null    object
#  5   channel1_arr_vals_raw  90 non-null     object
#  6   vals                   200 non-null    object
#  7   vals2                  90 non-null     object
# dtypes: int64(1), object(7)
# memory usage: 14.1+ KB

# %%
df_abund = generate_worm_params(df)
df_abund.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                290 non-null    object
#  1   diet_and_channel  290 non-null    object
#  2   stage             290 non-null    object
#  3   peaks             290 non-null    int64
#  4   avg_peak          290 non-null    float64
#  5   avg_peak_pos      207 non-null    float64
#  6   vals              290 non-null    object
#  7   total_peak_flo    290 non-null    float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 18.3+ KB

# %%
order = ['JUB66_RFP_ONTO_PA01_GFP_1', 'JUB66_RFP_IN_CEMBIO_ONTO_PA01_GFP_1']
fig, ax = significance_boxplot(df= df_abund, y='peaks', x='diet_and_channel', order=order)
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# JUB66_RFP_ONTO_PA01_GFP_1 vs. JUB66_RFP_IN_CEMBIO_ONTO_PA01_GFP_1: Brunner-Munzel test with Bonferroni correction, P_val:1.416e-01 W=-1.490e+00
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# JUB66_RFP_ONTO_PA01_GFP_1 vs. JUB66_RFP_IN_CEMBIO_ONTO_PA01_GFP_1: Brunner-Munzel test with Bonferroni correction, P_val:1.416e-01 W=-1.490e+00
