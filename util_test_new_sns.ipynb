# %%
from utils.utils import *
import seaborn as sns

# %%
df = load_and_clean()

# %%
df_sect = generate_section_params(df)

# %%
groups = ["JUB66_RFP_IN_CEMBIO_ONTO_PA01_GFP_1", "JUB66_RFP_ONTO_PA01_GFP_1"]

# %%
df_pathogen_plot = filter_on_diet_and_channel(df_sect, groups)

# %%
fig, ax = plot_spatial(df_pathogen_plot, 'sect', 'peaks', 'diet_and_channel')
