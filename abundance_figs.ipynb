# %%
from utils.statannotation_utils import *
from utils.utils import *

# %%
df = load_and_clean()

# %%
df_abund = generate_worm_params(df)
df_abund.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                290 non-null    object
#  1   diet_and_channel  290 non-null    object
#  2   stage             290 non-null    object
#  3   peaks             290 non-null    int64
#  4   avg_peak          290 non-null    float64
#  5   avg_peak_pos      207 non-null    float64
#  6   vals              290 non-null    object
#  7   total_peak_flo    290 non-null    float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 18.3+ KB

# %%
order = ["JUB66_RFP_0", "JUB66_RFP_IN_CEMBIO_0", "OP50_RFP_0", "MK_JUB66_RFP_IN_JUB66_0"]
baseline_abundance_fig, ax1 = significance_boxplot(df=df_abund, y='total_peak_flo', x = 'diet_and_channel', order=order)
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# JUB66_RFP_0 vs. JUB66_RFP_IN_CEMBIO_0: Brunner-Munzel test with Bonferroni correction, P_val:1.000e+00 W=2.160e-01
# JUB66_RFP_IN_CEMBIO_0 vs. OP50_RFP_0: Brunner-Munzel test with Bonferroni correction, P_val:2.839e-03 W=-3.792e+00
# OP50_RFP_0 vs. MK_JUB66_RFP_IN_JUB66_0: Brunner-Munzel test with Bonferroni correction, P_val:4.630e-03 W=-3.737e+00
# JUB66_RFP_0 vs. OP50_RFP_0: Brunner-Munzel test with Bonferroni correction, P_val:3.877e-02 W=-2.851e+00
# JUB66_RFP_IN_CEMBIO_0 vs. MK_JUB66_RFP_IN_JUB66_0: Brunner-Munzel test with Bonferroni correction, P_val:7.360e-22 W=-1.598e+01
# JUB66_RFP_0 vs. MK_JUB66_RFP_IN_JUB66_0: Brunner-Munzel test with Bonferroni correction, P_val:4.866e-10 W=-8.361e+00
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
# ...

# %%
baseline_abundance_fig.savefig('./output/figure2_abundance_w_points.svg')

# %%
order = ["JUB66_RFP_0", "JUB66_RFP_ONTO_PA01_GFP_0", "JUB66_RFP_ONTO_OP50_GFP_0"]
JUB66_abund, ax = significance_boxplot(df=df_abund, y='total_peak_flo', x='diet_and_channel', order=order)
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# JUB66_RFP_0 vs. JUB66_RFP_ONTO_PA01_GFP_0: Brunner-Munzel test with Bonferroni correction, P_val:1.259e-07 W=-6.764e+00
# JUB66_RFP_ONTO_PA01_GFP_0 vs. JUB66_RFP_ONTO_OP50_GFP_0: Brunner-Munzel test with Bonferroni correction, P_val:2.012e-05 W=-5.285e+00
# JUB66_RFP_0 vs. JUB66_RFP_ONTO_OP50_GFP_0: Brunner-Munzel test with Bonferroni correction, P_val:1.313e-17 W=-1.719e+01
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# JUB66_RFP_0 vs. JUB66_RFP_ONTO_PA01_GFP_0: Brunner-Munzel test with Bonferroni correction, P_val:1.259e-07 W=-6.764e+00
# ...

# %%
JUB66_abund.savefig('./output/figure3_abundance_w_points.svg')

# %%
order=["JUB66_RFP_0", "JUB66_RFP_ONTO_OP50_GFP_1", "OP50_RFP_0"]
fig, ax = significance_boxplot(df=df_abund, y='peaks', x='diet_and_channel', order=order)
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# JUB66_RFP_0 vs. JUB66_RFP_ONTO_OP50_GFP_1: Brunner-Munzel test with Bonferroni correction, P_val:1.007e-01 W=2.197e+00
# JUB66_RFP_ONTO_OP50_GFP_1 vs. OP50_RFP_0: Brunner-Munzel test with Bonferroni correction, P_val:6.067e-13 W=-1.103e+01
# JUB66_RFP_0 vs. OP50_RFP_0: Brunner-Munzel test with Bonferroni correction, P_val:2.695e-02 W=-2.725e+00
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# JUB66_RFP_0 vs. JUB66_RFP_ONTO_OP50_GFP_1: Brunner-Munzel test with Bonferroni correction, P_val:1.007e-01 W=2.197e+00
# JUB66_RFP_ONTO_OP50_GFP_1 vs. OP50_RFP_0: Brunner-Munzel test with Bonferroni correction, P_val:6.067e-13 W=-1.103e+01
# ...

# %%
fig.savefig('./output/figure4_OP50_abundance_w_points.svg')

# %%
order=["JUB66_RFP_IN_CEMBIO_ONTO_PA01_GFP_1", "JUB66_RFP_ONTO_PA01_GFP_1"]
PA01_abund, ax = significance_boxplot(df=df_abund, y='peaks', x='diet_and_channel', order=order)
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# JUB66_RFP_IN_CEMBIO_ONTO_PA01_GFP_1 vs. JUB66_RFP_ONTO_PA01_GFP_1: Brunner-Munzel test with Bonferroni correction, P_val:1.416e-01 W=1.490e+00
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# JUB66_RFP_IN_CEMBIO_ONTO_PA01_GFP_1 vs. JUB66_RFP_ONTO_PA01_GFP_1: Brunner-Munzel test with Bonferroni correction, P_val:1.416e-01 W=1.490e+00

# %%
PA01_abund.savefig('./output/figure4_PA01_abundance_w_points.svg')
